# %%
# %cd ../src
# Out:
# /home/ubuntu/SPVD_Lightning/src

# %%
import torch
torch.set_float32_matmul_precision('medium')

# %%
diffusion_steps = 1000
starting_checkpoint = f"../checkpoints/distillation/GSPVD/starting.ckpt"

model_args = {
    'voxel_size' : 0.1,
    'nfs' : (32, 64, 128, 256), 
    'attn_chans' : 8, 
    'attn_start' : 3, 
    'cross_attn_chans' : 8, 
    'cross_attn_start' : 2, 
    'cross_attn_cond_dim' : 768,
}

from distillation import DistillationProcess, Teacher, Student
distillation_agent = DistillationProcess(lr=1e-4)
# Out:
# /opt/conda/envs/spvd/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from datasets.shapenet.shapenet_loader import get_dataloaders

categories = ['bowl']
path = "../data/ShapeNet"
tr, te, val = get_dataloaders(path, categories=categories, load_renders=True, n_steps=diffusion_steps, batch_size=32)
# Out:
# Loading (train) renders for bowl (02880940): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 125/125 [00:00<00:00, 363.33it/s]
# Loading (test) renders for bowl (02880940): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 432.80it/s]
# Loading (val) renders for bowl (02880940): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 429.30it/s]

# %%
import torch
import lightning as L
from my_schedulers.ddim_scheduler import DDIMSparseScheduler

# %%
N = diffusion_steps
distillation_agent.set_teacher(Teacher(model_args, starting_checkpoint, N))

while N > 0:
    previous_checkpoint = starting_checkpoint if N == diffusion_steps else f"../checkpoints/distillation/GSPVD/{N}-steps.ckpt"
    
    N = (N + 1) // 2
    student_sched = DDIMSparseScheduler(steps=N, prev_alpha=distillation_agent.teacher.diffusion_scheduler.alpha)
    tr.dataset.set_scheduler(student_sched)
    te.dataset.set_scheduler(student_sched)
    val.dataset.set_scheduler(student_sched)

    distillation_agent.set_student(Student(model_args, previous_checkpoint, N, scheduler=student_sched))

    distillation_agent.check_initialization()

    max_epochs = 100
    trainer = L.Trainer(
        max_epochs=max_epochs, 
        callbacks=[],
        gradient_clip_val=10.0,
    )

    trainer.fit(distillation_agent, tr, val)
    print(f"Trained Student for {N} steps.")

    new_checkpoint = f"../checkpoints/distillation/GSPVD/{N}-steps.ckpt"
    torch.save(distillation_agent.student.state_dict(), new_checkpoint)
    distillation_agent.set_teacher(Teacher(model_args, new_checkpoint, N, student_sched))
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type    | Params | Mode
# --------------------------------------------
# 0 | teacher | Teacher | 25.0 M | eval
# 1 | student | Student | 25.0 M | train
# --------------------------------------------
# 25.0 M    Trainable params
# 25.0 M    Non-trainable params
# 50.0 M    Total params
# 200.030   Total estimated model params size (MB)
# 295       Modules in train mode
# 295       Modules in eval mode
# Initialization check passed for 500 steps.
# Sanity Checking: |                                                                                            …
# /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (4) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |                                                                                                   …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:574, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     568 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     569     self.state.fn,
#     570     ckpt_path,
#     571     model_provided=True,
#     572     model_connected=self.lightning_module is not None,
#     573 )
# --> 574 self._run(model, ckpt_path=ckpt_path)
#     576 assert self.state.stopped
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:981, in Trainer._run(self, model, ckpt_path)
#     978 # ----------------------------
#     979 # RUN THE TRAINER
#     980 # ----------------------------
# --> 981 results = self._run_stage()
#     983 # ----------------------------
#     984 # POST-Training CLEAN UP
#     985 # ----------------------------
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:1025, in Trainer._run_stage(self)
#    1024 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025     self.fit_loop.run()
#    1026 return None
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:206, in _FitLoop.run(self)
#     205 self.advance()
# --> 206 self.on_advance_end()
#     207 self._restarting = False
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:378, in _FitLoop.on_advance_end(self)
#     377 call._call_lightning_module_hook(trainer, "on_train_epoch_end")
# --> 378 call._call_callback_hooks(trainer, "on_train_epoch_end", monitoring_callbacks=True)
#     380 trainer._logger_connector.on_epoch_end()
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:218, in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     217         with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 218             fn(trainer, trainer.lightning_module, *args, **kwargs)
#     220 if pl_module:
#     221     # restore current_fx when nested context
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:325, in ModelCheckpoint.on_train_epoch_end(self, trainer, pl_module)
#     324 if self._every_n_epochs >= 1 and (trainer.current_epoch + 1) % self._every_n_epochs == 0:
# --> 325     self._save_topk_checkpoint(trainer, monitor_candidates)
#     326 self._save_last_checkpoint(trainer, monitor_candidates)
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:387, in ModelCheckpoint._save_topk_checkpoint(self, trainer, monitor_candidates)
#     386 else:
# --> 387     self._save_none_monitor_checkpoint(trainer, monitor_candidates)
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:715, in ModelCheckpoint._save_none_monitor_checkpoint(self, trainer, monitor_candidates)
#     714 previous, self.best_model_path = self.best_model_path, filepath
# --> 715 self._save_checkpoint(trainer, filepath)
#     717 if self.save_top_k == 1 and previous and self._should_remove_checkpoint(trainer, previous, filepath):
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:390, in ModelCheckpoint._save_checkpoint(self, trainer, filepath)
#     389 def _save_checkpoint(self, trainer: "pl.Trainer", filepath: str) -> None:
# --> 390     trainer.save_checkpoint(filepath, self.save_weights_only)
#     392     self._last_global_step_saved = trainer.global_step
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:1365, in Trainer.save_checkpoint(self, filepath, weights_only, storage_options)
#    1364 checkpoint = self._checkpoint_connector.dump_checkpoint(weights_only)
# -> 1365 self.strategy.save_checkpoint(checkpoint, filepath, storage_options=storage_options)
#    1366 self.strategy.barrier("Trainer.save_checkpoint")
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/strategies/strategy.py:490, in Strategy.save_checkpoint(self, checkpoint, filepath, storage_options)
#     489 if self.is_global_zero:
# --> 490     self.checkpoint_io.save_checkpoint(checkpoint, filepath, storage_options=storage_options)
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/fabric/plugins/io/torch_io.py:58, in TorchCheckpointIO.save_checkpoint(self, checkpoint, path, storage_options)
#      57 fs.makedirs(os.path.dirname(path), exist_ok=True)
# ---> 58 _atomic_save(checkpoint, path)
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/fabric/utilities/cloud_io.py:89, in _atomic_save(checkpoint, filepath)
#      88 fs, urlpath = fsspec.core.url_to_fs(str(filepath))
# ---> 89 with fs.transaction, fs.open(urlpath, "wb") as f:
#      90     f.write(bytesbuffer.getvalue())
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/fsspec/implementations/local.py:471, in LocalFileOpener.__exit__(self, exc_type, exc_value, traceback)
#     470 self._incontext = False
# --> 471 self.f.__exit__(exc_type, exc_value, traceback)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 24
#      17 max_epochs = 100
#      18 trainer = L.Trainer(
#      19     max_epochs=max_epochs,
#      20     callbacks=[],
#      21     gradient_clip_val=10.0,
#      22 )
# ---> 24 trainer.fit(distillation_agent, tr, val)
#      25 print(f"Trained Student for {N} steps.")
#      27 new_checkpoint = f"../checkpoints/distillation/GSPVD/{N}-steps.ckpt"
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/trainer.py:538, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536 self.state.status = TrainerStatus.RUNNING
#     537 self.training = True
# --> 538 call._call_and_handle_interrupt(
#     539     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540 )
#
# File /opt/conda/envs/spvd/lib/python3.10/site-packages/lightning/pytorch/trainer/call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
from my_schedulers.ddpm_scheduler import DDPMSparseScheduler
from utils.visualization import display_pointclouds_grid

# ddpm_sched = distillation_agent.teacher.diffusion_scheduler
ddpm_sched = distillation_agent.student.diffusion_scheduler

# %%
import numpy as np

samples = 16
references = [tr.dataset[idx] for idx in np.random.choice(list(range(len(tr.dataset))), size=(samples,))]
# references = [te.dataset[idx] for idx in np.random.choice(list(range(len(te.dataset))), size=(samples,))]

# %%
reference_images = torch.stack([r["render-features"] for r in references]).to("cuda")

distillation_agent.student = distillation_agent.student.cuda().eval()
distillation_agent.teacher = distillation_agent.teacher.cuda().eval()

# %%
preds = ddpm_sched.sample(distillation_agent.student.model, samples, 2048, reference=reference_images)
# preds = ddpm_sched.sample(distillation_agent.teacher.model, samples, 2048, reference=reference_images)

# %%
display_pointclouds_grid(preds.cpu().numpy(), offset=8, point_size=0.3)
