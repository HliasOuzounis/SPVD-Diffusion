# %%
# %cd ../src
# Out:
# /home/ubuntu/SPVD_Lightning/src

# %%
from my_models.spvd import SPVUnet

model_params = {
    "features": (32, 32, 64, 128, 256),
    "attn_heads_list": (None, None, None, 8),
    "cross_attn_heads_list": (None, None, 8, 8),
    "cross_attn_cond_dim": 768,
}

model = SPVUnet(**model_params)
# Out:
# [32, 32, 32, 64, 64, 128, 128, 256]
# SPVUnet(
#   (in_conv): Conv3d(3, 32, kernel_size=(3, 3, 3), bias=False)
#   (t_emb_mlp): Sequential(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): SiLU()
#     (2): Linear(in_features=32, out_features=128, bias=True)
#     (3): SiLU()
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (downs_blocks): ModuleList(
#     (0): DownBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(32, 32, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(32, 32, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Identity()
#         )
#       )
#       (down): Conv3d(32, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     )
#     (1): DownBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(32, 64, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(64, 64, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=32, out_features=64, bias=True)
#         )
#       )
#       (down): Conv3d(64, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     )
#     (2): DownBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(64, 128, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(128, 128, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=64, out_features=128, bias=True)
#           (cross_attn): SparseCrossAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#             )
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=128, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=128, out_features=128, bias=True)
#             )
#           )
#         )
#       )
#       (down): Conv3d(128, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     )
#     (3): DownBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(128, 256, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(256, 256, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=128, out_features=256, bias=True)
#           (attn): SparseAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (cross_attn): SparseCrossAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=256, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#           )
#         )
#       )
#       (down): Identity()
#     )
#   )
#   (mid_block): ModuleList(
#     (0): SharedMLP(
#       (layers): Sequential(
#         (0): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): SiLU()
#         (2): Linear(in_features=128, out_features=256, bias=True)
#       )
#     )
#   )
#   (ups_blocks): ModuleList(
#     (0): UpBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(512, 256, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(256, 256, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=512, out_features=256, bias=True)
#           (attn): SparseAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (cross_attn): SparseCrossAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=256, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#           )
#         )
#         (1): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(384, 256, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(256, 256, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=384, out_features=256, bias=True)
#           (attn): SparseAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (cross_attn): SparseCrossAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=256, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=256, out_features=256, bias=True)
#             )
#           )
#         )
#       )
#       (up_sample): Conv3d(256, 256, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False, transposed=True)
#     )
#     (1): UpBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(384, 128, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(128, 128, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=384, out_features=128, bias=True)
#           (cross_attn): SparseCrossAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#             )
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=128, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=128, out_features=128, bias=True)
#             )
#           )
#         )
#         (1): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(192, 128, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(128, 128, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=192, out_features=128, bias=True)
#           (cross_attn): SparseCrossAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#             )
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (mlp): Sequential(
#               (0): Linear(in_features=768, out_features=128, bias=True)
#               (1): GELU(approximate='none')
#               (2): Linear(in_features=128, out_features=128, bias=True)
#             )
#           )
#         )
#       )
#       (up_sample): Conv3d(128, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False, transposed=True)
#     )
#     (2): UpBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(192, 64, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(64, 64, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=192, out_features=64, bias=True)
#         )
#         (1): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(96, 64, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(64, 64, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=96, out_features=64, bias=True)
#         )
#       )
#       (up_sample): Conv3d(64, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False, transposed=True)
#     )
#     (3): UpBlock(
#       (res_blocks): ModuleList(
#         (0): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(96, 32, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(32, 32, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=96, out_features=32, bias=True)
#         )
#         (1): SparseResidualBlock(
#           (conv1): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(64, 32, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (conv2): SparseConv3DBlock(
#             (layers): Sequential(
#               (0): BatchNorm(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (1): SiLU()
#               (2): Conv3d(32, 32, kernel_size=(3, 3, 3), bias=False)
#             )
#           )
#           (t_embedding): TimeEmbeddingBlock()
#           (res_connection): Linear(in_features=64, out_features=32, bias=True)
#         )
#       )
#       (up_sample): Identity()
#     )
#   )
#   (point_branch): SharedMLP(
#     (layers): Sequential(
#       (0): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): SiLU()
#       (2): Linear(in_features=3, out_features=32, bias=True)
#     )
#   )
#   (out_conv): Sequential(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): SiLU()
#     (2): Linear(in_features=32, out_features=3, bias=False)
#   )
# )
