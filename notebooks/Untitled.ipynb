# %%
# %cd ../src
# Out:
# /home/ubuntu/SPVD_Lightning/src

# %%
from src.datasets.modelnet40 import get_dataloaders, ModelNet40Sparse
path = "../data/ModelNet40/pointclouds"
categories = ["xbox"]
tr, te = get_dataloaders(path, categories=categories)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from datasets.modelnet40 import get_dataloaders, ModelNet40Sparse
#       2 path = "../data/ModelNet40/pointclouds"
#       3 categories = ["xbox"]
#
# ModuleNotFoundError: No module named 'datasets.modelnet40'

# %%
import src.models as models

m = models.SPVD()

lr = 1e-4
model = models.DiffusionBase(m, lr=lr)

import lightning as L
trainer = L.Trainer(
    max_epochs=50, 
    gradient_clip_val=10.0,
)

trainer.fit(model=model, train_dataloaders=tr, val_dataloaders=te)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type    | Params | Mode
# ------------------------------------------
# 0 | model | SPVUnet | 32.9 M | train
# ------------------------------------------
# 32.9 M    Trainable params
# 0         Non-trainable params
# 32.9 M    Total params
# 131.576   Total estimated model params size (MB)
# 314       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |                                                                                            …
# Training: |                                                                                                   …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# Validation: |                                                                                                 …
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
from utils.visualization import visualize_notebook
from utils.schedulers import DDPMSparseSchedulerGPU

ddpm_sched = DDPMSparseSchedulerGPU(n_steps=1000, beta_min=0.0001, beta_max=0.02, pres=1e-5)

preds = ddpm_sched.sample(model.cuda(), 16, 2048)
visualize_notebook(preds, x_offset=2.5, y_offset=2.5, point_size=0.025)
